# %% [markdown]
# ### Load necessary libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Basic Graph

# %%
x=[0,1,2,3,4]
y= [0,2,4,6,8]

# Resize your graph

plt.figure(figsize=(5,3) , dpi=300)
#line 1

#Keyword Argument Notation
#plt.plot(x,y, label ='2x', color='red', linewidth = 2, linestyle ='--',
#          marker='.', markersize=10, markeredgecolor = 'blue')

#shorthand notation
#fmt = '[color][marker][line]'
# plt.plot(x,y, 'r.--', label ='2x')
plt.plot(x,y, 'b^--', label ='2x')


## Line 2

# select interval as we want to plot point at
x2 = np.arange(0,4.5,0.5)

#plot part of the graph as line
plt.plot(x2[:6] , x2[:6]**2, 'r', label ='X^2')

#plot remaining graph
plt.plot(x2[5:] , x2[5:]**2, 'r--' )

# Add a title (specify font parameter with fontdict)
plt.title('Our First Graph', fontdict ={'fontname':'Comic Sans MS', 
                'fontsize':20})

#X and Y labels
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# X and y tickmarks (scale of graph)
plt.xticks([0,1,2,3,4])
plt.yticks([0,2,4,6,8,10])

#add a legend
plt.legend()

#save figure (dpi 300)
plt.savefig('mygraph.png', dpi =300)

#show plot
plt.show()

# %% [markdown]
# ### Bar chart

# %%
labels =['A','B','C']
values =[1,4,2]

bars = plt.bar(labels,values)

patterns =['/','o','*']

for bar in bars:
    bar.set_hatch(patterns.pop(0))
    
# bars[0].set_hatch('/')
# bars[1].set_hatch('o')
# bars[2].set_hatch('*')

plt.figure(figsize =(6,4))

plt.show()
